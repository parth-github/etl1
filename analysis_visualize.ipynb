# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
cur_path = os.getcwd()
file = 'movies_transformed.csv'
file_path = os.path.join(cur_path, 'data_files', file )
print(file_path)

df = pd.read_csv(file_path)
# Out:
# e:\ETLProject1\etl1\data_files\movies_transformed.csv

# %%
x_coord = df['Runtime (Minutes)']
y_coord = df['Rating']

plt.scatter(x_coord, y_coord)


plt.show()

# %%
x_coord = df['Revenue (Millions)']
y_coord = df['Rating']

plt.scatter(x_coord, y_coord)


plt.show()

# %%
(df['Rating'] == 0).count()
# Out:
# 97

# %%
df = df.dropna(subset=['Rating'])

# %%
df.drop(df[df['Rating'] == 0].index, inplace=True)

# %%
y_coord = df['Revenue (Millions)']
y_coord = df['Votes']

plt.scatter(x_coord, y_coord)


plt.show()
